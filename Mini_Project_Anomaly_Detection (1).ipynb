# %% [markdown]
# # Anomaly Detection of Retail Store Sales
#
# This hands-on mini-project will enable you to reinforce your learnings pertaining to anomaly detection in this unit. By now, you must already be aware of the key objective of anomaly detection. Just to refresh your memory, anomaly detection is the identification of outliers or rare event items in a dataset which potentially exhibit abnormal behavior or properties as compared to the rest of the datapoints.
#
# There are a wide variety of anomaly detection methods including supervised, unsupervised and semi-supervised. Typically you can perform anomaly detection on univariate data, multivariate data as well as data which is temporal in nature. In this mini-project you will leverage state-of-the-art anomaly detection models from frameworks like [__`scikit-learn`__](https://scikit-learn.org/stable/modules/outlier_detection.html) and [__`PyOD`__](https://pyod.readthedocs.io/en/latest/index.html).
#
#
# By the end of this mini-project, you will have successfully applied these techniques to find out potential outliers pertaining to sales transactional data in a retail store dataset and also learnt how to visualize outliers similar to the following plot.
#
# ![](outlier_ex.png)
#
# We will be performing anomaly detection on both univariate and multivariate data and leverage the following anomaly detection techniques.
#
# - Simple Statistical Models (mean & standard deviation: the three-sigma rule)
# - Isolation Forest
# - Clustering-Based Local Outlier Factor
# - Auto-encoders

# %% [markdown]
# # 1. Getting and Loading the Dataset
#
# The first step towards solving any data science or machine learning problem is to obtain the necessary data. In this scenario, we will be dealing with a popular retail dataset known as the [SuperStore Sales Dataset](https://community.tableau.com/docs/DOC-1236) which consists of transactional data pertaining to a retail store.
#
# #### Please download the required dataset from [here](https://community.tableau.com/docs/DOC-1236) if necessary, although it will also be provided to you along with this notebook for this mini-project
#
# Once we have the necessary data, we will load up the dataset and perform some initial exploratory data analysis

# %% [markdown]
# # 2. Exploratory Data Analysis
#
# It's time to do some basic exploratory analysis on the retail store transactional data. We start by loading up the dataset into a pandas dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline


df = pd.read_excel("./Superstore.xls")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %% [markdown]
# We don't have any major missing values in our dataset and we can now look at a sample subset of the data

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Visualize Sales vs. Order Date
#
# Let's look more closely at the __`Sales`__ attribute of the dataset in the next few cells. We'll start by looking at typical sales over time

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
sns.lineplot(x=df['Order Date'], y=df['Sales']);

# %% [markdown]
# ## Visualize Sales Distribution
#
#
# Let's now look at the data distribution for __`Sales`__

# %%
sns.distplot(df['Sales'])
plt.title("Sales Distribution");

# %%
df['Sales'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %% [markdown]
# We can definitely see the presence of potential outliers in terms of the min or max values as compared to the meat of the distribution in the interquartile range as observed in the distribution statistics

# %% [markdown]
# ## Q 2.1: Visualize Profit vs. Order Date
#
# Let's now look closely at the __`Profit`__ attribute of the dataset in the next few cells. We'll start by looking at typical profits over time.
#
# __Your turn: Plot `Order Date` vs. `Profit` using a line plot__

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))
sns.lineplot(x=df['Order Date'], y=df['Profit'])
# Out:
# <Axes: xlabel='Order Date', ylabel='Profit'>

# %% [markdown]
# ## Q 2.2: Visualize Profit Distribution
#
# Let's now look at the data distribution for __`Profit`__
#
# __Your turn: Plot the distribution for `Profit`__

# %%
sns.distplot(df['Profit'])
# Out:
# <Axes: xlabel='Profit', ylabel='Density'>

# %% [markdown]
# __Your turn: Get the essential descriptive statistics for `Profit` using an appropriate function__

# %%
df['Profit'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9994 entries, 0 to 9993
# Series name: Profit
# Non-Null Count  Dtype
# --------------  -----
# 9994 non-null   float64
# dtypes: float64(1)
# memory usage: 78.2 KB

# %% [markdown]
# __Your turn: Do you notice anything interesting about the distribution?__

# %% [markdown]
# We have both positive and negative values in profits since it indicates either a profit or a loss based on the sales and original price of the items.

# %% [markdown]
# ## Visualize Discount vs. Profit

# %%
sns.scatterplot(x="Discount", y="Profit", data=df);

# %% [markdown]
# In the above visual, we look at a scatter plot showing the distribution of profits w.r.t discounts given

# %% [markdown]
# # 3. Univariate Anomaly Detection
#
# Univariate is basically analysis done on a single attribute or feature. In this section, we will perform anomaly detection on a single attribute using the following methods.
#
# - Statistical Process Control Methods (mean + 3sigma thresholding)
# - Isolation Forest
#
# We will start off by demonstrating both these techniques on the __`Sales`__ attribute and later on, you will implement similar techniques on the __`Profit`__ attribute.

# %% [markdown]
# ## 3.1: Univariate Anomaly Detection on Sales using Statistical Modeling
#
# Here we start off by implementing anomaly detecting using statistical modeling on the __`Sales`__ attribute

# %% [markdown]
# ### Obtain Upper Limit Threshold for Sales
#
# Here we are concerned about transactions with high sales values so we compute the upper limit using the $\mu$ + 3$\sigma$ rule where $\mu$ is the mean of the distribution and $\sigma$ is the standard deviation of the distribution.

# %%
mean_sales = df['Sales'].mean()
sigma_sales = df['Sales'].std()
three_sigma_sales = 3*sigma_sales

threshold_sales_value = mean_sales + three_sigma_sales
print('Threshold Sales:', threshold_sales_value)
# Out:
# Threshold Sales: 2099.593302356541

# %% [markdown]
# ### Visualize Outlier Region

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

sns.distplot(df['Sales'])
plt.axvspan(threshold_sales_value, df['Sales'].max(), facecolor='r', alpha=0.3)
plt.title("Sales Distribution with Outlier Region");

# %% [markdown]
# ### Filter and Sort Outliers
#
# Here we filter out the outlier observations and sort by descending order and view the top 5 outlier values

# %%
sales_outliers_df = df['Sales'][df['Sales'] > threshold_sales_value]
print('Total Sales Outliers:', len(sales_outliers_df))
sales_outliers_sorted = sales_outliers_df.sort_values(ascending=False)
sales_outliers_sorted.head(5)
# Out:
# Total Sales Outliers: 127
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
# Name: Sales, dtype: float64

# %% [markdown]
# ### View Top 10 Outlier Transactions

# %%
(df.loc[sales_outliers_sorted.index.tolist()][['City', 'Category', 'Sub-Category', 'Product Name',
                                              'Sales', 'Quantity', 'Discount', 'Profit']]).head(10)
# Out:
#                City         Category Sub-Category  \
# 2697   Jacksonville       Technology     Machines
# 6826      Lafayette       Technology      Copiers
# 8153        Seattle       Technology      Copiers
# 2623  New York City       Technology      Copiers
# 4190         Newark       Technology      Copiers
# 9039        Detroit  Office Supplies      Binders
# 4098    Minneapolis  Office Supplies      Binders
# 4277       Lakewood       Technology     Machines
# 8488      Arlington       Technology     Machines
# 6425   Philadelphia       Technology      Copiers
#
#                                            Product Name      Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.480         6
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.950         5
# 8153              Canon imageCLASS 2200 Advanced Copier  13999.960         4
# 2623              Canon imageCLASS 2200 Advanced Copier  11199.968         4
# 4190              Canon imageCLASS 2200 Advanced Copier  10499.970         3
# 9039   GBC Ibimaster 500 Manual ProClick Binding System   9892.740        13
# 4098               Ibico EPK-21 Electric Binding System   9449.950         5
# 4277   3D Systems Cube Printer, 2nd Generation, Magenta   9099.930         7
# 8488  HP Designjet T520 Inkjet Large Format Printer ...   8749.950         5
# 6425              Canon imageCLASS 2200 Advanced Copier   8399.976         4
#
#       Discount     Profit
# 2697       0.5 -1811.0784
# 6826       0.0  8399.9760
# 8153       0.0  6719.9808
# 2623       0.2  3919.9888
# 4190       0.0  5039.9856
# 9039       0.0  4946.3700
# 4098       0.0  4630.4755
# 4277       0.0  2365.9818
# 8488       0.0  2799.9840
# 6425       0.4  1119.9968

# %% [markdown]
# ### View Bottom 10 Outlier Transactions

# %%
(df.loc[sales_outliers_sorted.index.tolist()][['City', 'Category', 'Sub-Category', 'Product Name',
                                              'Sales', 'Quantity', 'Discount', 'Profit']]).tail(10)
# Out:
#                City         Category Sub-Category  \
# 5300    Springfield        Furniture       Tables
# 6101  New York City        Furniture       Chairs
# 4881      Henderson       Technology  Accessories
# 7487          Dover       Technology  Accessories
# 1155   Harrisonburg        Furniture       Tables
# 8699      Nashville       Technology       Phones
# 9774    San Antonio  Office Supplies      Binders
# 8424       Lakewood        Furniture    Bookcases
# 6534        Buffalo  Office Supplies      Binders
# 8680       Richmond  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 5300                  Hon Rectangular Conference Tables  2275.500        10
# 6101      Global Troy Executive Leather Low-Back Tilter  2254.410         5
# 4881                      Logitech diNovo Edge Keyboard  2249.910         9
# 7487                      Logitech diNovo Edge Keyboard  2249.910         9
# 1155  Chromcraft 48" x 96" Racetrack Double Pedestal...  2244.480         7
# 8699  Samsung Galaxy S III - 16GB - pebble blue (T-M...  2239.936         8
# 9774          GBC DocuBind P400 Electric Binding System  2177.584         8
# 8424  Global Adaptabilites Bookcase, Cherry/Storm Gr...  2154.900         5
# 6534         GBC DocuBind TL300 Electric Binding System  2152.776         3
# 8680  Honeywell Enviracaire Portable HEPA Air Cleane...  2104.550         7
#
#       Discount     Profit
# 5300       0.0   386.8350
# 6101       0.1   375.7350
# 4881       0.0   517.4793
# 7487       0.0   517.4793
# 1155       0.0   493.7856
# 8699       0.2   223.9936
# 9774       0.8 -3701.8928
# 8424       0.0   129.2940
# 6534       0.2   726.5619
# 8680       0.0   694.5015

# %% [markdown]
# ## Q 3.2: Univariate Anomaly Detection on Profit using Statistical Modeling
#
# In this section you will use the learning from Section 3.1 and implement anomaly detecting using statistical modeling on the __`Profit`__ attribute. Since we have both +ve (profits) and -ve (losses) values in the distribution, we will try to find anomalies for each.

# %% [markdown]
# ### Obtain Upper Limit Threshold for Profit
#
# __Your turn:__ Compute the upper and lower limits using the  𝜇  + 3 𝜎  rule where  𝜇  is the mean of the distribution and  𝜎  is the standard deviation of the distribution.

# %%
mean_profit = df['Profit'].mean()
sigma_profit = df['Profit'].std()
three_sigma_profit = 3*sigma_profit

threshold_profit_upper_limit = mean_profit + (3 * sigma_profit)
threshold_profit_lower_limit = mean_profit - (3 * sigma_profit)


print('Thresholds Profit:', threshold_profit_lower_limit, threshold_profit_upper_limit)
# Out:
# Thresholds Profit: -674.1234267650873 731.4372193806566

# %% [markdown]
# ### Visualize Outlier Regions
#
# __Your turn:__ Visualize the upper and lower outlier regions in the distribution similar to what you did in 3.1

# %%
fig, ax = plt.subplots(1, 1, figsize=(12, 6))

sns.distplot(df['Profit'])
plt.axvspan(-float('inf'), threshold_profit_lower_limit, facecolor='r', alpha=0.3)  # Shading the left side (outliers)
plt.axvspan(threshold_profit_upper_limit, float('inf'), facecolor='r', alpha=0.3)  # Shading the right side (outliers)
plt.title('Profit distribution with outlier region')
# Out:
# Text(0.5, 1.0, 'Profit distribution with outlier region')

# %% [markdown]
# ### Filter and Sort Outliers
#
# __Your turn:__ Filter out the outlier observations and sort by descending order and view the top 5 outlier values

# %%
sorted_for_lowest_profit = df['Profit'].sort_values()

sorted_for_lowest_profit.head()
# Out:
# 7772   -6599.9780
# 683    -3839.9904
# 9774   -3701.8928
# 3011   -3399.9800
# 4991   -2929.4845
# Name: Profit, dtype: float64

# %% [markdown]
# ### View Top 10 Outlier Transactions
#
# __Your turn:__ View the top ten transactions based on highest profits

# %%
sorted_for_highest_profit = df.sort_values(by='Profit', ascending=False)

filtered_top_profit = sorted_for_highest_profit['Profit']
filtered_top_profit.head(10)
# Out:
# 6826    8399.9760
# 8153    6719.9808
# 4190    5039.9856
# 9039    4946.3700
# 4098    4630.4755
# 2623    3919.9888
# 509     3177.4750
# 8488    2799.9840
# 7666    2591.9568
# 6520    2504.2216
# Name: Profit, dtype: float64

# %% [markdown]
# ### Q: Do you notice any interesting insights based on these transactions?

# %% [markdown]
# __A:__ Most of these are purchases for Copiers and Binders , looks like Canon products yielded some good profits`

# %% [markdown]
# ### View Bottom 10 Outlier Transactions
#
# __Your turn:__ View the bottom ten transactions based on lowest profits (highest losses)

# %%
sorted_for_lowest_profit.head(10)
# Out:
# 7772   -6599.9780
# 683    -3839.9904
# 9774   -3701.8928
# 3011   -3399.9800
# 4991   -2929.4845
# 3151   -2639.9912
# 5310   -2287.7820
# 9639   -1862.3124
# 1199   -1850.9464
# 2697   -1811.0784
# Name: Profit, dtype: float64

# %% [markdown]
# ### Q: Do you notice any interesting insights based on these transactions?

# %% [markdown]
# __A:__ Most of these are purchases for Machines and Binders , looks like Cibify 3D Printers yielded high losses

# %% [markdown]
# ## 3.3: Univariate Anomaly Detection on Sales using Isolation Forest
#
# You might have already learnt about this model from the curriculum. Just to briefly recap, the Isolation Forest model,  'isolates' observations by randomly selecting a feature and then randomly selecting a split value between the maximum and minimum values of the selected feature.
#
# Recursive partitioning can be represented by a tree structure. Hence, the number of splittings required to isolate a sample is equivalent to the path length from the root node to the terminating node. This path length, averaged over a forest of such random trees, is a measure of normality and our decision function.
#
# Random partitioning produces noticeably shorter paths for anomalies. Hence, when a forest of random trees collectively produce shorter path lengths for particular samples, they are highly likely to be anomalies.
#
# More details are available in this [User Guide](https://scikit-learn.org/stable/modules/outlier_detection.html#isolation-forest)

# %% [markdown]
# ### Initialize and Train Model
#
# Here we initialize the isolation forest model with some hyperparameters assuming the proportion of outliers to be 1% of the total data (using the `contamination` setting)

# %%
from sklearn.ensemble import IsolationForest

sales_ifmodel = IsolationForest(n_estimators=100,
                                contamination=0.01)
sales_ifmodel.fit(df[['Sales']])
# Out:
# IsolationForest(contamination=0.01)

# %% [markdown]
# ### Visualize Outlier Region
#
# Here we visualize the outlier region in the data distribution

# %%
xx = np.linspace(df['Sales'].min(), df['Sales'].max(), len(df)).reshape(-1,1)
anomaly_score = sales_ifmodel.decision_function(xx)
outlier = sales_ifmodel.predict(xx)
plt.figure(figsize=(12, 6))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score),
                 where=outlier==-1, color='r',
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Sales');

# %% [markdown]
# ### Filter and Sort Outliers
#
# Here we predict outliers in our dataset using our trained model and filter out the outlier observations and sort by descending order and view the top 5 outlier values

# %%
outlier_predictions = sales_ifmodel.predict(df[['Sales']])

sales_outliers_df = df[['Sales']]
sales_outliers_df['Outlier'] = outlier_predictions
sales_outliers_df = sales_outliers_df[sales_outliers_df['Outlier'] == -1]['Sales']

print('Total Sales Outliers:', len(sales_outliers_df))
sales_outliers_sorted = sales_outliers_df.sort_values(ascending=False)
sales_outliers_sorted.head(5)
# Out:
# Total Sales Outliers: 100
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
# Name: Sales, dtype: float64

# %% [markdown]
# ### View Top 10 Outlier Transactions

# %%
(df.loc[sales_outliers_sorted.index.tolist()][['City', 'Category', 'Sub-Category', 'Product Name',
                                              'Sales', 'Quantity', 'Discount', 'Profit']]).head(10)
# Out:
#                City         Category Sub-Category  \
# 2697   Jacksonville       Technology     Machines
# 6826      Lafayette       Technology      Copiers
# 8153        Seattle       Technology      Copiers
# 2623  New York City       Technology      Copiers
# 4190         Newark       Technology      Copiers
# 9039        Detroit  Office Supplies      Binders
# 4098    Minneapolis  Office Supplies      Binders
# 4277       Lakewood       Technology     Machines
# 8488      Arlington       Technology     Machines
# 6425   Philadelphia       Technology      Copiers
#
#                                            Product Name      Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.480         6
# 6826              Canon imageCLASS 2200 Advanced Copier  17499.950         5
# 8153              Canon imageCLASS 2200 Advanced Copier  13999.960         4
# 2623              Canon imageCLASS 2200 Advanced Copier  11199.968         4
# 4190              Canon imageCLASS 2200 Advanced Copier  10499.970         3
# 9039   GBC Ibimaster 500 Manual ProClick Binding System   9892.740        13
# 4098               Ibico EPK-21 Electric Binding System   9449.950         5
# 4277   3D Systems Cube Printer, 2nd Generation, Magenta   9099.930         7
# 8488  HP Designjet T520 Inkjet Large Format Printer ...   8749.950         5
# 6425              Canon imageCLASS 2200 Advanced Copier   8399.976         4
#
#       Discount     Profit
# 2697       0.5 -1811.0784
# 6826       0.0  8399.9760
# 8153       0.0  6719.9808
# 2623       0.2  3919.9888
# 4190       0.0  5039.9856
# 9039       0.0  4946.3700
# 4098       0.0  4630.4755
# 4277       0.0  2365.9818
# 8488       0.0  2799.9840
# 6425       0.4  1119.9968

# %% [markdown]
# ### View Bottom 10 Outlier Transactions

# %%
(df.loc[sales_outliers_sorted.index.tolist()][['City', 'Category', 'Sub-Category', 'Product Name',
                                              'Sales', 'Quantity', 'Discount', 'Profit']]).tail(10)
# Out:
#                City         Category Sub-Category  \
# 1805    Los Angeles       Technology       Phones
# 7474      Henderson        Furniture       Chairs
# 6884    Minneapolis        Furniture       Chairs
# 8271  New York City        Furniture       Chairs
# 3011     Louisville       Technology     Machines
# 6010    Los Angeles       Technology     Machines
# 7280       Columbia  Office Supplies      Binders
# 263         Houston       Technology     Machines
# 7937      Brentwood  Office Supplies   Appliances
# 3443  New York City  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 1805                              Samsung Galaxy Note 2  2575.944         7
# 7474            Global Deluxe High-Back Manager's Chair  2573.820         9
# 6884                         Hon Pagoda Stacking Chairs  2567.840         8
# 8271  Hon 4700 Series Mobuis Mid-Back Task Chairs wi...  2563.056         8
# 3011          Lexmark MX611dhe Monochrome Laser Printer  2549.985         5
# 6010  Zebra GX420t Direct Thermal/Thermal Transfer P...  2548.560         6
# 7280  Fellowes PB500 Electric Punch Plastic Comb Bin...  2541.980         2
# 263   Xerox WorkCentre 6505DN Laser Multifunction Pr...  2519.958         7
# 7937  Sanyo 2.5 Cubic Foot Mid-Size Office Refrigera...  2518.290         9
# 3443     Hoover Shoulder Vac Commercial Portable Vacuum  2504.740         7
#
#       Discount     Profit
# 1805       0.2   257.5944
# 7474       0.0   746.4078
# 6884       0.0   770.3520
# 8271       0.1   313.2624
# 3011       0.7 -3399.9800
# 6010       0.2   286.7130
# 7280       0.0  1270.9900
# 263        0.4  -251.9958
# 7937       0.0   654.7554
# 3443       0.0   626.1850

# %% [markdown]
# ## Q 3.4: Univariate Anomaly Detection on Profit using Isolation Forest
#
# In this section you will use the learning from Section 3.3 and implement anomaly detecting using isolation on the __`Profit`__ attribute. Since we have both +ve (profits) and -ve (losses) values in the distribution, we will try to find anomalies for each.

# %% [markdown]
# ### Initialize and Train Model
#
# __Your Turn:__ Initialize the isolation forest model with similar hyperparameters as Section 3.3 and also assuming the proportion of outliers to be 1% of the total data (using the contamination setting)

# %%
from sklearn.ensemble import IsolationForest

profit_ifmodel = IsolationForest(n_estimators=100,
                                contamination=0.01)
profit_ifmodel.fit(df[['Profit']])
# Out:
# IsolationForest(contamination=0.01)

# %% [markdown]
# ### Visualize Outlier Regions
#
# __Your turn:__ Visualize the upper and lower outlier regions in the distribution similar to what you did in 3.3

# %%
xx = np.linspace(df['Profit'].min(), df['Profit'].max(), len(df)).reshape(-1,1)
anomaly_score = profit_ifmodel.decision_function(xx)
outlier = profit_ifmodel.predict(xx)
plt.figure(figsize=(12, 6))
plt.plot(xx, anomaly_score, label='anomaly score')
plt.fill_between(xx.T[0], np.min(anomaly_score), np.max(anomaly_score),
                 where=outlier==-1, color='r',
                 alpha=.4, label='outlier region')
plt.legend()
plt.ylabel('anomaly score')
plt.xlabel('Profit');

print(xx)
# Out:
# [[-6599.978     ]
#  [-6598.47695387]
#  [-6596.97590774]
#  ...
#  [ 8396.97390774]
#  [ 8398.47495387]
#  [ 8399.976     ]]

# %% [markdown]
# ### Filter and Sort Outliers
#
# __Your Turn:__ Predict outliers in our dataset using our trained model and filter out the outlier observations and sort by descending order and view the top 5 outlier values similar to 3.3

# %%
outlier_predictions = profit_ifmodel.predict(df[['Profit']])

profit_outliers_df = df[['Profit']]
profit_outliers_df['Outlier'] = outlier_predictions
profit_outliers_df = profit_outliers_df[(profit_outliers_df['Outlier'] > threshold_profit_upper_limit) |
 (profit_outliers_df['Outlier'] < threshold_profit_lower_limit)]['Profit']

print('Total Profit Outliers:', len(profit_outliers_df))
profit_outliers_sorted = profit_outliers_df.sort_values(ascending=False)
profit_outliers_sorted.head(5)
# Out:
# Total Profit Outliers: 0
# Series([], Name: Profit, dtype: float64)

# %% [markdown]
# ### View Top 10 Outlier Transactions
#
# __Your turn:__ View the top ten transactions based on highest profits

# %%
print(xx[-10:])
# Out:
# [[8386.46658481]
#  [8387.96763094]
#  [8389.46867707]
#  [8390.96972321]
#  [8392.47076934]
#  [8393.97181547]
#  [8395.4728616 ]
#  [8396.97390774]
#  [8398.47495387]
#  [8399.976     ]]

# %% [markdown]
# ### View Bottom 10 Outlier Transactions
#
# __Your turn:__ View the bottom ten transactions based on lowest profits (highest losses)

# %%
print(xx[:10])
# Out:
# [[-6599.978     ]
#  [-6598.47695387]
#  [-6596.97590774]
#  [-6595.4748616 ]
#  [-6593.97381547]
#  [-6592.47276934]
#  [-6590.97172321]
#  [-6589.47067707]
#  [-6587.96963094]
#  [-6586.46858481]]

# %% [markdown]
# ### Q: Do you observe any similarity in the results with the previous method?

# %% [markdown]
# __A:__ Yes

# %% [markdown]
# Another interesting approach to check out would be the [Generalized ESD Test for Outliers](https://www.itl.nist.gov/div898/handbook/eda/section3/eda35h3.htm)

# %% [markdown]
# # 4. Multivariate Anomaly Detection
#
# Multivariate is basically analysis done on more than one attribute or feature at a time. In this section, we will perform anomaly detection on two attributes (__`Discount`__ & __`Profit`__) using the following methods.
#
# - Clustering Based Local Outlier Factor (CBLOF)
# - Isolation Forest
# - Auto-Encoders
#
# You will learn how to train these models to detect outliers and also visualize these outliers. For this section we will be using the __[`pyod`](https://pyod.readthedocs.io/en/latest/)__ package so make sure you have it installed.

# %%
# !pip install pyod
# Out:
# Collecting pyod
#   Downloading pyod-1.1.0.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from pyod) (1.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from pyod) (3.7.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.23.5)
# Requirement already satisfied: numba>=0.51 in /usr/local/lib/python3.10/dist-packages (from pyod) (0.56.4)
# Requirement already satisfied: scipy>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.11.2)
# Requirement already satisfied: scikit_learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from pyod) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pyod) (1.16.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.51->pyod) (67.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>=0.20.0->pyod) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->pyod) (2.8.2)
# Building wheels for collected packages: pyod
#   Building wheel for pyod (setup.py) ... done
#   Created wheel for pyod: filename=pyod-1.1.0-py3-none-any.whl size=185329 sha256=c79bdeb0d8ea448634be6c6899fc65dc5a1a1d91f0aa0951b5a2e14ca80aaa1e
#   Stored in directory: /root/.cache/pip/wheels/36/8e/e2/e932956b10b843eb6be9eefa70b5c1bee7b561be14c423b136
# Successfully built pyod
# Installing collected packages: pyod
# Successfully installed pyod-1.1.0

# %% [markdown]
# ## Extract Subset Data for Outlier Detection

# %%
cols = ['Discount', 'Profit']
subset_df = df[cols]
subset_df.head()
# Out:
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler(feature_range=(0, 1))
subset_df[cols] = mms.fit_transform(subset_df)
subset_df.head()
# Out:
#    Discount    Profit
# 0    0.0000  0.442794
# 1    0.0000  0.454639
# 2    0.0000  0.440458
# 3    0.5625  0.414464
# 4    0.2500  0.440168

# %% [markdown]
# ## 4.1: Multivariate Anomaly Detection with Clustering Based Local Outlier Factor (CBLOF)
#
# The CBLOF model takes as an input the dataset and the cluster model that was generated by a clustering algorithm. It classifies the clusters into small clusters and large clusters using the parameters alpha and beta. The anomaly score is then calculated based on the size of the cluster the point belongs to as well as the distance to the nearest large cluster.
#
# By default, kMeans is used for clustering algorithm. You can read more in the [official documentation](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.cblof)

# %% [markdown]
# ### Initialize and Train Model
#
# Here we initialize the CBLOF model with some hyperparameters assuming the proportion of outliers to be 1% of the total data (using the `contamination` setting)

# %%
from pyod.models import cblof

cblof_model = cblof.CBLOF(contamination=0.01, random_state=42)
cblof_model.fit(subset_df)
# Out:
# CBLOF(alpha=0.9, beta=5, check_estimator=False, clustering_estimator=None,
#    contamination=0.01, n_clusters=8, n_jobs=None, random_state=42,
#    use_weights=False)

# %% [markdown]
# ### Filter and Sort Outliers
#
# Here we predict outliers in our dataset using our trained model and filter out the outlier observations and sort by descending order and view the top 5 outlier values

# %%
outlier_predictions = cblof_model.predict(subset_df)

outliers_df = subset_df.copy(deep=True)
outliers_df['Outlier'] = outlier_predictions
outliers_df = outliers_df[outliers_df['Outlier'] == 1]

print('Total Outliers:', len(outliers_df))
outliers_sorted = outliers_df.sort_values(by=['Profit', 'Discount'], ascending=False)
outliers_sorted.head(5)
# Out:
# Total Outliers: 100
#       Discount    Profit  Outlier
# 6826       0.0  1.000000        1
# 8153       0.0  0.888000        1
# 4190       0.0  0.776000        1
# 9039       0.0  0.769759        1
# 4098       0.0  0.748699        1

# %% [markdown]
# ### View Bottom 10 Outlier Transactions

# %%
(df.loc[outliers_sorted.index.tolist()][['City', 'Category', 'Sub-Category', 'Product Name',
                                              'Sales', 'Quantity', 'Discount', 'Profit']]).tail(10)
# Out:
#               City    Category Sub-Category  \
# 463        Phoenix   Furniture       Tables
# 4128     Charlotte  Technology     Machines
# 8993      Columbia   Furniture       Tables
# 5320     Knoxville   Furniture       Tables
# 165    San Antonio  Technology     Machines
# 27    Philadelphia   Furniture    Bookcases
# 2697  Jacksonville  Technology     Machines
# 9639       Concord   Furniture       Tables
# 683     Burlington  Technology     Machines
# 7772     Lancaster  Technology     Machines
#
#                                            Product Name      Sales  Quantity  \
# 463   Bush Advantage Collection Racetrack Conference...   1272.630         6
# 4128  HP Designjet T520 Inkjet Large Format Printer ...   2624.985         3
# 8993                       Balt Solid Wood Round Tables   1875.258         7
# 5320  Chromcraft Bull-Nose Wood Oval Conference Tabl...   2314.116         7
# 165           Lexmark MX611dhe Monochrome Laser Printer   8159.952         8
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...   3083.430         7
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.480         6
# 9639  Chromcraft Bull-Nose Wood Oval Conference Tabl...   4297.644        13
# 683           Cubify CubeX 3D Printer Triple Head Print   7999.980         4
# 7772          Cubify CubeX 3D Printer Double Head Print   4499.985         5
#
#       Discount     Profit
# 463        0.5  -814.4832
# 4128       0.5  -944.9946
# 8993       0.4  -968.8833
# 5320       0.4 -1002.7836
# 165        0.4 -1359.9920
# 27         0.5 -1665.0522
# 2697       0.5 -1811.0784
# 9639       0.4 -1862.3124
# 683        0.5 -3839.9904
# 7772       0.7 -6599.9780

# %% [markdown]
# We can definitely see some huge losses incurred based on giving higher discounts even if the sales amount was high which is interesting as well as concerning.

# %% [markdown]
# ## Q 4.2: Multivariate Anomaly Detection with Isolation Forest
#
# Here you will detect anomalies using the Isolation Forest model and use the learnings from 4.1. Here you will use the [`pyod`](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.iforest) version of [Isolation Forest](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.iforest) which is basically a wrapper over the `scikit-learn` version but with more functionalities.

# %% [markdown]
# ### Initialize and Train Model
#
# __Your Turn:__ Initialize the isolation forest model with similar hyperparameters as before and also assuming the proportion of outliers to be 1% of the total data (using the contamination setting)

# %%
from pyod.models.iforest import IForest

if_model = IForest(n_estimators=100, contamination=0.01)

if_model.fit(df[cols])
outlier_predictions = if_model.predict(df[cols])
outliers_df = df[outlier_predictions == 1]
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 27       28  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 165     166  CA-2014-139892 2014-09-08 2014-09-12  Standard Class    BM-11140
# 169     170  CA-2014-139892 2014-09-08 2014-09-12  Standard Class    BM-11140
# 215     216  CA-2015-146262 2015-01-02 2015-01-09  Standard Class    VW-21775
# 318     319  CA-2014-164973 2014-11-04 2014-11-09  Standard Class    NM-18445
#
#        Customer Name      Segment        Country           City  ...  \
# 27   Tracy Blumstein     Consumer  United States   Philadelphia  ...
# 165     Becky Martin     Consumer  United States    San Antonio  ...
# 169     Becky Martin     Consumer  United States    San Antonio  ...
# 215  Victoria Wilson    Corporate  United States         Medina  ...
# 318     Nathan Mautz  Home Office  United States  New York City  ...
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 27        19140     East  FUR-BO-10004834        Furniture    Bookcases
# 165       78207  Central  TEC-MA-10000822       Technology     Machines
# 169       78207  Central  OFF-AP-10002518  Office Supplies   Appliances
# 215       44256     East  TEC-MA-10000864       Technology     Machines
# 318       10024     East  TEC-MA-10002927       Technology     Machines
#
#                                           Product Name     Sales  Quantity  \
# 27   Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430         7
# 165          Lexmark MX611dhe Monochrome Laser Printer  8159.952         8
# 169       Kensington 7 Outlet MasterPiece Power Center   177.980         5
# 215                 Cisco 9971 IP Video Phone Charcoal  1188.000         9
# 318  Canon imageCLASS MF7460 Monochrome Digital Las...  3991.980         2
#
#      Discount     Profit
# 27        0.5 -1665.0522
# 165       0.4 -1359.9920
# 169       0.8  -453.8490
# 215       0.7  -950.4000
# 318       0.0  1995.9900
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Filter and Sort Outliers
#
# __Your Turn:__ Predict outliers in our dataset using our trained model and filter out the outlier observations and sort by descending order and view the top 5 outlier values similar to 4.1

# %%
outliers_df_sorted = outliers_df.sort_values(by=cols)

outliers_df_sorted.head(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6527    6528  CA-2016-157791 2016-12-23 2016-12-28    Second Class
# 7583    7584  CA-2014-163223 2014-03-21 2014-03-25  Standard Class
# 9741    9742  CA-2015-117086 2015-11-08 2015-11-12  Standard Class
# 5006    5007  CA-2015-169796 2015-11-09 2015-11-14  Standard Class
# 2182    2183  CA-2016-128818 2016-05-07 2016-05-11  Standard Class
# 2492    2493  CA-2014-144624 2014-11-19 2014-11-23  Standard Class
# 2848    2849  CA-2017-157854 2017-04-08 2017-04-15  Standard Class
# 7280    7281  CA-2015-162782 2015-02-21 2015-02-27  Standard Class
# 994      995  CA-2014-117639 2014-05-21 2014-05-25  Standard Class
# 6340    6341  CA-2017-143112 2017-10-05 2017-10-09  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 6527    CA-11965       Carol Adams    Corporate  United States
# 7583    KH-16690  Kristen Hastings    Corporate  United States
# 9741    QJ-19255      Quincy Jones    Corporate  United States
# 5006    Dp-13240       Dean percer  Home Office  United States
# 2182    CJ-12010   Caroline Jumper     Consumer  United States
# 2492    JM-15865       John Murray     Consumer  United States
# 2848    DM-13345     Denise Monton    Corporate  United States
# 7280    PW-19240      Pierre Wener     Consumer  United States
# 994     MW-18235  Mitch Willingham    Corporate  United States
# 6340    TS-21370      Todd Sumrall    Corporate  United States
#
#                 City  ... Postal Code  Region       Product ID  \
# 6527         Warwick  ...        2886    East  TEC-CO-10002095
# 7583     Springfield  ...       22153   South  TEC-PH-10000730
# 9741      Burlington  ...        5408    East  FUR-BO-10004834
# 5006   New York City  ...       10035    East  TEC-MA-10000045
# 2182   New York City  ...       10009    East  TEC-MA-10000488
# 2492       Jamestown  ...       14701    East  TEC-PH-10002885
# 2848         Roswell  ...       30076   South  OFF-BI-10001359
# 7280        Columbia  ...       21044    East  OFF-BI-10003527
# 994   Virginia Beach  ...       23464   South  OFF-BI-10003925
# 6340   New York City  ...       10035    East  TEC-MA-10001047
#
#              Category Sub-Category  \
# 6527       Technology      Copiers
# 7583       Technology       Phones
# 9741        Furniture    Bookcases
# 5006       Technology     Machines
# 2182       Technology     Machines
# 2492       Technology       Phones
# 2848  Office Supplies      Binders
# 7280  Office Supplies      Binders
# 994   Office Supplies      Binders
# 6340       Technology     Machines
#
#                                            Product Name    Sales  Quantity  \
# 6527  Hewlett Packard 610 Color Digital Copier / Pri...  1999.96         4
# 7583                           Samsung Galaxy S4 Active  3499.93         7
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90         5
# 5006                  Zebra ZM400 Thermal Label Printer  2321.90         2
# 2182                        Bady BDG101FRU Card Printer  3999.95         5
# 2492                                     Apple iPhone 5  4548.81         7
# 2848         GBC DocuBind TL300 Electric Binding System  2690.97         3
# 7280  Fellowes PB500 Electric Punch Plastic Comb Bin...  2541.98         2
# 994         Fellowes PB300 Plastic Comb Binding Machine  2715.93         7
# 6340   3D Systems Cube Printer, 2nd Generation, Magenta  5199.96         4
#
#       Discount     Profit
# 6527       0.0   899.9820
# 7583       0.0   909.9818
# 9741       0.0  1013.1270
# 5006       0.0  1114.5120
# 2182       0.0  1159.9855
# 2492       0.0  1228.1787
# 2848       0.0  1264.7559
# 7280       0.0  1270.9900
# 994        0.0  1276.4871
# 6340       0.0  1351.9896
#
# [10 rows x 21 columns]

# %% [markdown]
# ### View Bottom 10 Outlier Transactions
#
# __Your turn:__ View the bottom ten transactions

# %%
outliers_df_sorted.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6035    6036  US-2015-155369 2015-04-19 2015-04-25  Standard Class
# 8251    8252  CA-2015-140221 2015-03-05 2015-03-09    Second Class
# 7348    7349  CA-2014-130421 2014-03-03 2014-03-07  Standard Class
# 169      170  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# 6566    6567  CA-2017-131282 2017-02-05 2017-02-08    Second Class
# 3084    3085  CA-2017-118773 2017-02-09 2017-02-14  Standard Class
# 9164    9165  CA-2015-164007 2015-06-08 2015-06-12  Standard Class
# 3141    3142  US-2014-122959 2014-12-12 2014-12-12        Same Day
# 679      680  US-2017-119438 2017-03-18 2017-03-23  Standard Class
# 4082    4083  US-2017-151316 2017-06-24 2017-06-30  Standard Class
#
#      Customer ID        Customer Name    Segment        Country         City  \
# 6035    PG-18820      Patrick Gardner   Consumer  United States   Carrollton
# 8251    MS-17365  Maribeth Schnelling   Consumer  United States      Chicago
# 7348    SC-20020           Sam Craven   Consumer  United States      Houston
# 169     BM-11140         Becky Martin   Consumer  United States  San Antonio
# 6566    CB-12025    Cassandra Brandow   Consumer  United States         Waco
# 3084    TP-21415         Tom Prescott   Consumer  United States      Houston
# 9164    MG-17695        Maureen Gnade   Consumer  United States      Chicago
# 3141    CY-12745         Craig Yedwab  Corporate  United States  San Antonio
# 679     CD-11980         Carol Darley   Consumer  United States        Tyler
# 4082    MC-17635       Matthew Clasen  Corporate  United States      Decatur
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 6035  ...       75007  Central  OFF-BI-10003925  Office Supplies      Binders
# 8251  ...       60653  Central  OFF-AP-10000828  Office Supplies   Appliances
# 7348  ...       77095  Central  OFF-AP-10002534  Office Supplies   Appliances
# 169   ...       78207  Central  OFF-AP-10002518  Office Supplies   Appliances
# 6566  ...       76706  Central  OFF-BI-10004632  Office Supplies      Binders
# 3084  ...       77070  Central  OFF-BI-10004584  Office Supplies      Binders
# 9164  ...       60610  Central  OFF-AP-10003849  Office Supplies   Appliances
# 3141  ...       78207  Central  OFF-BI-10003650  Office Supplies      Binders
# 679   ...       75701  Central  OFF-BI-10004632  Office Supplies      Binders
# 4082  ...       62521  Central  OFF-BI-10004632  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 6035        Fellowes PB300 Plastic Comb Binding Machine  310.392         4
# 8251                    Avanti 4.4 Cu. Ft. Refrigerator  180.980         5
# 7348  3.6 Cubic Foot Counter Height Office Refrigerator  176.772         3
# 169        Kensington 7 Outlet MasterPiece Power Center  177.980         5
# 6566                Ibico Hi-Tech Manual Binding System  243.992         4
# 3084       GBC ProClick 150 Presentation Binding System  252.784         4
# 9164     Hoover Shoulder Vac Commercial Portable Vacuum  143.128         2
# 3141          GBC DocuBind 300 Electric Binding Machine  210.392         2
# 679                 Ibico Hi-Tech Manual Binding System  182.994         3
# 4082                Ibico Hi-Tech Manual Binding System  182.994         3
#
#       Discount    Profit
# 6035       0.8 -512.1468
# 8251       0.8 -470.5480
# 7348       0.8 -459.6072
# 169        0.8 -453.8490
# 6566       0.8 -426.9860
# 3084       0.8 -417.0936
# 9164       0.8 -393.6020
# 3141       0.8 -336.6272
# 679        0.8 -320.2395
# 4082       0.8 -320.2395
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Q: Do you notice any differences in the results with the previous model?

# %% [markdown]
# We do notice some transactions with 80% discount and high losses

# %% [markdown]
# ## Q 4.3: Multivariate Anomaly Detection with Auto-encoders
#
# Here you will detect anomalies using the Auto-encoder model and use the learnings from 4.1. Here you will use the [Auto-encoder](https://pyod.readthedocs.io/en/latest/pyod.models.html#module-pyod.models.auto_encoder) model from `pyod` which is a deep learning model often used for learning useful data representations in an unsupervised fashion without any labeled data.
#
# ![](outlier_ae.png)
#
# Similar to PCA, AE could be used to detect outlier objects in the data by calculating the reconstruction errors

# %% [markdown]
# ### Initialize Model
#
# Here we initiaze an auto-encoder network with a few hidden layers so that we could train it for a 100 epochs

# %%
from pyod.models import auto_encoder

ae_model = auto_encoder.AutoEncoder(hidden_neurons=[2, 32, 32, 2],
                                    hidden_activation='relu',
                                    output_activation='sigmoid',
                                    epochs=100,
                                    batch_size=32,
                                    contamination=0.01)

# %% [markdown]
# ### Train Model
#
# __Your turn:__ Train the model by calling the `fit()` function on the right data

# %%
ae_model.fit(outliers_df[cols])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dropout (Dropout)           (None, 2)                 0
#
#  dense_1 (Dense)             (None, 2)                 6
#
#  dropout_1 (Dropout)         (None, 2)                 0
#
#  dense_2 (Dense)             (None, 2)                 6
#
#  dropout_2 (Dropout)         (None, 2)                 0
#
#  dense_3 (Dense)             (None, 32)                96
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 2)                 66
#
#  dropout_5 (Dropout)         (None, 2)                 0
#
#  dense_6 (Dense)             (None, 2)                 6
#
# =================================================================
# Total params: 1242 (4.85 KB)
# Trainable params: 1242 (4.85 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/100
# 3/3 [==============================] - 7s 316ms/step - loss: 1.4333 - val_loss: 1.3995
# Epoch 2/100
# 3/3 [==============================] - 0s 35ms/step - loss: 1.4308 - val_loss: 1.3966
# Epoch 3/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.4281 - val_loss: 1.3938
# Epoch 4/100
# 3/3 [==============================] - 0s 45ms/step - loss: 1.4256 - val_loss: 1.3911
# Epoch 5/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4234 - val_loss: 1.3883
# Epoch 6/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.4220 - val_loss: 1.3857
# Epoch 7/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4187 - val_loss: 1.3831
# Epoch 8/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.4181 - val_loss: 1.3805
# Epoch 9/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.4145 - val_loss: 1.3779
# Epoch 10/100
# 3/3 [==============================] - 0s 44ms/step - loss: 1.4119 - val_loss: 1.3753
# Epoch 11/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.4097 - val_loss: 1.3727
# Epoch 12/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.4075 - val_loss: 1.3702
# Epoch 13/100
# 3/3 [==============================] - 0s 66ms/step - loss: 1.4053 - val_loss: 1.3677
# Epoch 14/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.4032 - val_loss: 1.3651
# Epoch 15/100
# 3/3 [==============================] - 0s 71ms/step - loss: 1.4013 - val_loss: 1.3626
# Epoch 16/100
# 3/3 [==============================] - 0s 80ms/step - loss: 1.4002 - val_loss: 1.3601
# Epoch 17/100
# 3/3 [==============================] - 0s 87ms/step - loss: 1.3981 - val_loss: 1.3576
# Epoch 18/100
# 3/3 [==============================] - 0s 91ms/step - loss: 1.3946 - val_loss: 1.3552
# Epoch 19/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.3931 - val_loss: 1.3527
# Epoch 20/100
# 3/3 [==============================] - 0s 92ms/step - loss: 1.3906 - val_loss: 1.3503
# Epoch 21/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3895 - val_loss: 1.3479
# Epoch 22/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3868 - val_loss: 1.3456
# Epoch 23/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.3851 - val_loss: 1.3432
# Epoch 24/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3834 - val_loss: 1.3408
# Epoch 25/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1.3802 - val_loss: 1.3385
# Epoch 26/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3783 - val_loss: 1.3362
# Epoch 27/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.3763 - val_loss: 1.3340
# Epoch 28/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.3744 - val_loss: 1.3318
# Epoch 29/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3734 - val_loss: 1.3296
# Epoch 30/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3709 - val_loss: 1.3274
# Epoch 31/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3688 - val_loss: 1.3252
# Epoch 32/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3668 - val_loss: 1.3231
# Epoch 33/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3648 - val_loss: 1.3210
# Epoch 34/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3635 - val_loss: 1.3189
# Epoch 35/100
# 3/3 [==============================] - 0s 46ms/step - loss: 1.3611 - val_loss: 1.3169
# Epoch 36/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3597 - val_loss: 1.3148
# Epoch 37/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.3576 - val_loss: 1.3127
# Epoch 38/100
# 3/3 [==============================] - 0s 42ms/step - loss: 1.3557 - val_loss: 1.3107
# Epoch 39/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3540 - val_loss: 1.3087
# Epoch 40/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3523 - val_loss: 1.3067
# Epoch 41/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3506 - val_loss: 1.3047
# Epoch 42/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.3486 - val_loss: 1.3027
# Epoch 43/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.3470 - val_loss: 1.3008
# Epoch 44/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3453 - val_loss: 1.2988
# Epoch 45/100
# 3/3 [==============================] - 0s 23ms/step - loss: 1.3435 - val_loss: 1.2969
# Epoch 46/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3421 - val_loss: 1.2950
# Epoch 47/100
# 3/3 [==============================] - 0s 36ms/step - loss: 1.3400 - val_loss: 1.2931
# Epoch 48/100
# 3/3 [==============================] - 0s 47ms/step - loss: 1.3384 - val_loss: 1.2912
# Epoch 49/100
# 3/3 [==============================] - 0s 28ms/step - loss: 1.3367 - val_loss: 1.2894
# Epoch 50/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3354 - val_loss: 1.2875
# Epoch 51/100
# 3/3 [==============================] - 0s 29ms/step - loss: 1.3335 - val_loss: 1.2856
# Epoch 52/100
# 3/3 [==============================] - 0s 24ms/step - loss: 1.3317 - val_loss: 1.2838
# Epoch 53/100
# 3/3 [==============================] - 0s 37ms/step - loss: 1.3302 - val_loss: 1.2820
# Epoch 54/100
# 3/3 [==============================] - 0s 32ms/step - loss: 1.3288 - val_loss: 1.2802
# Epoch 55/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.3270 - val_loss: 1.2784
# Epoch 56/100
# 3/3 [==============================] - 0s 61ms/step - loss: 1.3254 - val_loss: 1.2766
# Epoch 57/100
# 3/3 [==============================] - 0s 48ms/step - loss: 1.3244 - val_loss: 1.2749
# Epoch 58/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.3221 - val_loss: 1.2732
# Epoch 59/100
# 3/3 [==============================] - 0s 41ms/step - loss: 1.3209 - val_loss: 1.2714
# Epoch 60/100
# 3/3 [==============================] - 0s 27ms/step - loss: 1.3190 - val_loss: 1.2697
# Epoch 61/100
# 3/3 [==============================] - 0s 39ms/step - loss: 1.3176 - val_loss: 1.2680
# Epoch 62/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.3160 - val_loss: 1.2663
# Epoch 63/100
# 3/3 [==============================] - 0s 108ms/step - loss: 1.3145 - val_loss: 1.2646
# Epoch 64/100
# 3/3 [==============================] - 0s 67ms/step - loss: 1.3132 - val_loss: 1.2629
# Epoch 65/100
# 3/3 [==============================] - 0s 89ms/step - loss: 1.3115 - val_loss: 1.2613
# Epoch 66/100
# 3/3 [==============================] - 0s 108ms/step - loss: 1.3100 - val_loss: 1.2597
# Epoch 67/100
# 3/3 [==============================] - 0s 75ms/step - loss: 1.3085 - val_loss: 1.2580
# Epoch 68/100
# 3/3 [==============================] - 0s 59ms/step - loss: 1.3070 - val_loss: 1.2564
# Epoch 69/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.3056 - val_loss: 1.2549
# Epoch 70/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.3042 - val_loss: 1.2533
# Epoch 71/100
# 3/3 [==============================] - 0s 86ms/step - loss: 1.3028 - val_loss: 1.2517
# Epoch 72/100
# 3/3 [==============================] - 0s 75ms/step - loss: 1.3013 - val_loss: 1.2501
# Epoch 73/100
# 3/3 [==============================] - 0s 56ms/step - loss: 1.3001 - val_loss: 1.2486
# Epoch 74/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2989 - val_loss: 1.2470
# Epoch 75/100
# 3/3 [==============================] - 0s 72ms/step - loss: 1.2971 - val_loss: 1.2455
# Epoch 76/100
# 3/3 [==============================] - 0s 83ms/step - loss: 1.2961 - val_loss: 1.2441
# Epoch 77/100
# 3/3 [==============================] - 0s 114ms/step - loss: 1.2944 - val_loss: 1.2426
# Epoch 78/100
# 3/3 [==============================] - 0s 74ms/step - loss: 1.2930 - val_loss: 1.2411
# Epoch 79/100
# 3/3 [==============================] - 0s 73ms/step - loss: 1.2916 - val_loss: 1.2397
# Epoch 80/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2909 - val_loss: 1.2382
# Epoch 81/100
# 3/3 [==============================] - 0s 50ms/step - loss: 1.2890 - val_loss: 1.2367
# Epoch 82/100
# 3/3 [==============================] - 0s 60ms/step - loss: 1.2876 - val_loss: 1.2353
# Epoch 83/100
# 3/3 [==============================] - 0s 34ms/step - loss: 1.2868 - val_loss: 1.2338
# Epoch 84/100
# 3/3 [==============================] - 0s 40ms/step - loss: 1.2850 - val_loss: 1.2324
# Epoch 85/100
# 3/3 [==============================] - 0s 30ms/step - loss: 1.2841 - val_loss: 1.2310
# Epoch 86/100
# 3/3 [==============================] - 0s 75ms/step - loss: 1.2825 - val_loss: 1.2297
# Epoch 87/100
# 3/3 [==============================] - 0s 70ms/step - loss: 1.2811 - val_loss: 1.2283
# Epoch 88/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.2798 - val_loss: 1.2270
# Epoch 89/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.2786 - val_loss: 1.2256
# Epoch 90/100
# 3/3 [==============================] - 0s 54ms/step - loss: 1.2774 - val_loss: 1.2243
# Epoch 91/100
# 3/3 [==============================] - 0s 53ms/step - loss: 1.2760 - val_loss: 1.2229
# Epoch 92/100
# 3/3 [==============================] - 0s 55ms/step - loss: 1.2748 - val_loss: 1.2216
# Epoch 93/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2737 - val_loss: 1.2203
# Epoch 94/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2724 - val_loss: 1.2190
# Epoch 95/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2712 - val_loss: 1.2177
# Epoch 96/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2700 - val_loss: 1.2164
# Epoch 97/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2687 - val_loss: 1.2151
# Epoch 98/100
# 3/3 [==============================] - 0s 17ms/step - loss: 1.2676 - val_loss: 1.2139
# Epoch 99/100
# 3/3 [==============================] - 0s 18ms/step - loss: 1.2664 - val_loss: 1.2126
# Epoch 100/100
# 3/3 [==============================] - 0s 16ms/step - loss: 1.2652 - val_loss: 1.2114
# 4/4 [==============================] - 0s 3ms/step
# AutoEncoder(batch_size=32, contamination=0.01, dropout_rate=0.2, epochs=100,
#       hidden_activation='relu', hidden_neurons=[2, 32, 32, 2],
#       l2_regularizer=0.1,
#       loss=<function mean_squared_error at 0x7be9fd9a35b0>,
#       optimizer='adam', output_activation='sigmoid', preprocessing=True,
#       random_state=None, validation_size=0.1, verbose=1)

# %% [markdown]
# ### Filter and Sort Outliers
#
# __Your Turn:__ Predict outliers in our dataset using our trained model and filter out the outlier observations and sort by descending order and view the top 5 outlier values similar to 4.1

# %%
outliers_df_sorted.head(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6527    6528  CA-2016-157791 2016-12-23 2016-12-28    Second Class
# 7583    7584  CA-2014-163223 2014-03-21 2014-03-25  Standard Class
# 9741    9742  CA-2015-117086 2015-11-08 2015-11-12  Standard Class
# 5006    5007  CA-2015-169796 2015-11-09 2015-11-14  Standard Class
# 2182    2183  CA-2016-128818 2016-05-07 2016-05-11  Standard Class
# 2492    2493  CA-2014-144624 2014-11-19 2014-11-23  Standard Class
# 2848    2849  CA-2017-157854 2017-04-08 2017-04-15  Standard Class
# 7280    7281  CA-2015-162782 2015-02-21 2015-02-27  Standard Class
# 994      995  CA-2014-117639 2014-05-21 2014-05-25  Standard Class
# 6340    6341  CA-2017-143112 2017-10-05 2017-10-09  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 6527    CA-11965       Carol Adams    Corporate  United States
# 7583    KH-16690  Kristen Hastings    Corporate  United States
# 9741    QJ-19255      Quincy Jones    Corporate  United States
# 5006    Dp-13240       Dean percer  Home Office  United States
# 2182    CJ-12010   Caroline Jumper     Consumer  United States
# 2492    JM-15865       John Murray     Consumer  United States
# 2848    DM-13345     Denise Monton    Corporate  United States
# 7280    PW-19240      Pierre Wener     Consumer  United States
# 994     MW-18235  Mitch Willingham    Corporate  United States
# 6340    TS-21370      Todd Sumrall    Corporate  United States
#
#                 City  ... Postal Code  Region       Product ID  \
# 6527         Warwick  ...        2886    East  TEC-CO-10002095
# 7583     Springfield  ...       22153   South  TEC-PH-10000730
# 9741      Burlington  ...        5408    East  FUR-BO-10004834
# 5006   New York City  ...       10035    East  TEC-MA-10000045
# 2182   New York City  ...       10009    East  TEC-MA-10000488
# 2492       Jamestown  ...       14701    East  TEC-PH-10002885
# 2848         Roswell  ...       30076   South  OFF-BI-10001359
# 7280        Columbia  ...       21044    East  OFF-BI-10003527
# 994   Virginia Beach  ...       23464   South  OFF-BI-10003925
# 6340   New York City  ...       10035    East  TEC-MA-10001047
#
#              Category Sub-Category  \
# 6527       Technology      Copiers
# 7583       Technology       Phones
# 9741        Furniture    Bookcases
# 5006       Technology     Machines
# 2182       Technology     Machines
# 2492       Technology       Phones
# 2848  Office Supplies      Binders
# 7280  Office Supplies      Binders
# 994   Office Supplies      Binders
# 6340       Technology     Machines
#
#                                            Product Name    Sales  Quantity  \
# 6527  Hewlett Packard 610 Color Digital Copier / Pri...  1999.96         4
# 7583                           Samsung Galaxy S4 Active  3499.93         7
# 9741  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90         5
# 5006                  Zebra ZM400 Thermal Label Printer  2321.90         2
# 2182                        Bady BDG101FRU Card Printer  3999.95         5
# 2492                                     Apple iPhone 5  4548.81         7
# 2848         GBC DocuBind TL300 Electric Binding System  2690.97         3
# 7280  Fellowes PB500 Electric Punch Plastic Comb Bin...  2541.98         2
# 994         Fellowes PB300 Plastic Comb Binding Machine  2715.93         7
# 6340   3D Systems Cube Printer, 2nd Generation, Magenta  5199.96         4
#
#       Discount     Profit
# 6527       0.0   899.9820
# 7583       0.0   909.9818
# 9741       0.0  1013.1270
# 5006       0.0  1114.5120
# 2182       0.0  1159.9855
# 2492       0.0  1228.1787
# 2848       0.0  1264.7559
# 7280       0.0  1270.9900
# 994        0.0  1276.4871
# 6340       0.0  1351.9896
#
# [10 rows x 21 columns]

# %% [markdown]
# ### View Bottom 10 Outlier Transactions
#
# __Your turn:__ View the bottom ten transactions

# %%
outliers_df_sorted.tail(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6035    6036  US-2015-155369 2015-04-19 2015-04-25  Standard Class
# 8251    8252  CA-2015-140221 2015-03-05 2015-03-09    Second Class
# 7348    7349  CA-2014-130421 2014-03-03 2014-03-07  Standard Class
# 169      170  CA-2014-139892 2014-09-08 2014-09-12  Standard Class
# 6566    6567  CA-2017-131282 2017-02-05 2017-02-08    Second Class
# 3084    3085  CA-2017-118773 2017-02-09 2017-02-14  Standard Class
# 9164    9165  CA-2015-164007 2015-06-08 2015-06-12  Standard Class
# 3141    3142  US-2014-122959 2014-12-12 2014-12-12        Same Day
# 679      680  US-2017-119438 2017-03-18 2017-03-23  Standard Class
# 4082    4083  US-2017-151316 2017-06-24 2017-06-30  Standard Class
#
#      Customer ID        Customer Name    Segment        Country         City  \
# 6035    PG-18820      Patrick Gardner   Consumer  United States   Carrollton
# 8251    MS-17365  Maribeth Schnelling   Consumer  United States      Chicago
# 7348    SC-20020           Sam Craven   Consumer  United States      Houston
# 169     BM-11140         Becky Martin   Consumer  United States  San Antonio
# 6566    CB-12025    Cassandra Brandow   Consumer  United States         Waco
# 3084    TP-21415         Tom Prescott   Consumer  United States      Houston
# 9164    MG-17695        Maureen Gnade   Consumer  United States      Chicago
# 3141    CY-12745         Craig Yedwab  Corporate  United States  San Antonio
# 679     CD-11980         Carol Darley   Consumer  United States        Tyler
# 4082    MC-17635       Matthew Clasen  Corporate  United States      Decatur
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 6035  ...       75007  Central  OFF-BI-10003925  Office Supplies      Binders
# 8251  ...       60653  Central  OFF-AP-10000828  Office Supplies   Appliances
# 7348  ...       77095  Central  OFF-AP-10002534  Office Supplies   Appliances
# 169   ...       78207  Central  OFF-AP-10002518  Office Supplies   Appliances
# 6566  ...       76706  Central  OFF-BI-10004632  Office Supplies      Binders
# 3084  ...       77070  Central  OFF-BI-10004584  Office Supplies      Binders
# 9164  ...       60610  Central  OFF-AP-10003849  Office Supplies   Appliances
# 3141  ...       78207  Central  OFF-BI-10003650  Office Supplies      Binders
# 679   ...       75701  Central  OFF-BI-10004632  Office Supplies      Binders
# 4082  ...       62521  Central  OFF-BI-10004632  Office Supplies      Binders
#
#                                            Product Name    Sales  Quantity  \
# 6035        Fellowes PB300 Plastic Comb Binding Machine  310.392         4
# 8251                    Avanti 4.4 Cu. Ft. Refrigerator  180.980         5
# 7348  3.6 Cubic Foot Counter Height Office Refrigerator  176.772         3
# 169        Kensington 7 Outlet MasterPiece Power Center  177.980         5
# 6566                Ibico Hi-Tech Manual Binding System  243.992         4
# 3084       GBC ProClick 150 Presentation Binding System  252.784         4
# 9164     Hoover Shoulder Vac Commercial Portable Vacuum  143.128         2
# 3141          GBC DocuBind 300 Electric Binding Machine  210.392         2
# 679                 Ibico Hi-Tech Manual Binding System  182.994         3
# 4082                Ibico Hi-Tech Manual Binding System  182.994         3
#
#       Discount    Profit
# 6035       0.8 -512.1468
# 8251       0.8 -470.5480
# 7348       0.8 -459.6072
# 169        0.8 -453.8490
# 6566       0.8 -426.9860
# 3084       0.8 -417.0936
# 9164       0.8 -393.6020
# 3141       0.8 -336.6272
# 679        0.8 -320.2395
# 4082       0.8 -320.2395
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 4.4: Visualize Anomalies and Compare Anomaly Detection Models
#
# Here we will look at the visual plots of anomalies as detected by the above three models

# %%
def visualize_anomalies(model, xx, yy, data_df, ax_obj, subplot_title):

    # predict raw anomaly score
    scores_pred = model.decision_function(data_df) * -1
    # prediction of a datapoint category outlier or inlier
    y_pred = model.predict(data_df)
    n_inliers = len(y_pred) - np.count_nonzero(y_pred)
    n_outliers = np.count_nonzero(y_pred == 1)


    out_df = data_df.copy(deep=True)
    out_df['Outlier'] = y_pred.tolist()
    # discount - inlier feature 1,  profit - inlier feature 2
    inliers_discount = out_df[out_df['Outlier'] == 0]['Discount'].values
    inliers_profit = out_df[out_df['Outlier'] == 0]['Profit'].values
    # discount - outlier feature 1, profit - outlier feature 2
    outliers_discount = out_df[out_df['Outlier'] == 1]['Discount'].values
    outliers_profit = out_df[out_df['Outlier'] == 1]['Profit'].values

    # Use threshold value to consider a datapoint inlier or outlier
    # threshold = stats.scoreatpercentile(scores_pred,100 * outliers_fraction)
    threshold = np.percentile(scores_pred, 100 * outliers_fraction)
    # decision function calculates the raw anomaly score for every point
    Z = model.decision_function(np.c_[xx.ravel(), yy.ravel()]) * -1
    Z = Z.reshape(xx.shape)
    # fill blue map colormap from minimum anomaly score to threshold value
    ax_obj.contourf(xx, yy, Z, levels=np.linspace(Z.min(), threshold, 7),cmap=plt.cm.Blues_r)
    # draw red contour line where anomaly score is equal to thresold
    a = ax_obj.contour(xx, yy, Z, levels=[threshold],linewidths=2, colors='red')
    # fill orange contour lines where range of anomaly score is from threshold to maximum anomaly score
    ax_obj.contourf(xx, yy, Z, levels=[threshold, Z.max()],colors='orange')
    b = ax_obj.scatter(inliers_discount, inliers_profit, c='white',s=20, edgecolor='k')
    c = ax_obj.scatter(outliers_discount, outliers_profit, c='black',s=20, edgecolor='k')


    ax_obj.legend([a.collections[0], b,c], ['learned decision function', 'inliers','outliers'],
               prop=matplotlib.font_manager.FontProperties(size=10),loc='upper right')

    ax_obj.set_xlim((0, 1))
    ax_obj.set_ylim((0, 1))
    ax_obj.set_xlabel('Discount')
    ax_obj.set_ylabel('Sales')
    ax_obj.set_title(subplot_title)
